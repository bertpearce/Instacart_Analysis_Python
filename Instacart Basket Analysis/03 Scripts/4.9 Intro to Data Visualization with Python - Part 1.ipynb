# %% [markdown]
# ## 00. Table of Contents

# %% [markdown]
# 01. Import Libraries
# 02. Import Data
# 03. Create functions, customize settings, and verify DataFrame
# 04. Wrangle data
# 05. Combine DataFrames
# 06. Export Data

# %% [markdown]
# ## 01. Import libraries

# %%
# Import coding libraries
import pandas as pd
import numpy as np
import os

# Import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# Confirm execution
print(f"Import libraries completed")
# Out:
# Import libraries completed

# %% [markdown]
# ## 02. Import data

# %%
# Import file as a DataFrame.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'customers.csv'
df_customers = pd.read_csv(os.path.join(folder_path, '02 Data', 'Original Data', file_name), index_col = False)
df_customers
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
# Import file as a DataFrame.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'ords_prods_agg.pkl'
df_ords_prods = pd.read_pickle(os.path.join(folder_path, '02 Data', 'Prepared Data', file_name))
df_ords_prods
# Out:
#           Unnamed: 0   order_id  user_id  order_number  orders_day_of_week  \
# 0                0.0  2539329.0      1.0           1.0                 2.0
# 1                1.0  2398795.0      1.0           2.0                 3.0
# 2                2.0   473747.0      1.0           3.0                 3.0
# 3                3.0  2254736.0      1.0           4.0                 4.0
# 4                4.0   431534.0      1.0           5.0                 4.0
# ...              ...        ...      ...           ...                 ...
# 32435065         NaN        NaN      NaN           NaN                 NaN
# 32435066         NaN        NaN      NaN           NaN                 NaN
# 32435067         NaN        NaN      NaN           NaN                 NaN
# 32435068         NaN        NaN      NaN           NaN                 NaN
# 32435069         NaN        NaN      NaN           NaN                 NaN
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# ## 03. Create functions, customize settings, and verify DataFrame

# %%
# Set display option to show all columns
pd.set_option('display.max_columns', None)

# Define and execute DataFrame verification function.
def verify_df(df):
    """
    Prints the shape and the first n rows of a DataFrame.
    
    Parameters:
    DF : The DataFrame to display.
    n (int) : The number of rows to display from the top of the DataFrame. Default is 5.
    """
    print(f"Shape of the DataFrame: {df.shape}")
    print(f"\nDataFrame Preview:\n", df)

# Verify DataFrame
verify_df(df_customers)
# Out:
# Shape of the DataFrame: (206209, 10)
#
# DataFrame Preview:
#          user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# ...

# %%
# Verify DataFrame
verify_df(df_ords_prods)
# Out:
# Shape of the DataFrame: (32435070, 26)
#
# DataFrame Preview:
#            Unnamed: 0   order_id  user_id  order_number  orders_day_of_week  \
# 0                0.0  2539329.0      1.0           1.0                 2.0
# 1                1.0  2398795.0      1.0           2.0                 3.0
# 2                2.0   473747.0      1.0           3.0                 3.0
# 3                3.0  2254736.0      1.0           4.0                 4.0
# 4                4.0   431534.0      1.0           5.0                 4.0
# ...              ...        ...      ...           ...                 ...
# 32435065         NaN        NaN      NaN           NaN                 NaN
# 32435066         NaN        NaN      NaN           NaN                 NaN
# 32435067         NaN        NaN      NaN           NaN                 NaN
# 32435068         NaN        NaN      NaN           NaN                 NaN
# 32435069         NaN        NaN      NaN           NaN                 NaN
#
# ...

# %% [markdown]
# ## 04. Wrangle data

# %% [markdown]
# ### 04.01. DataFrame format

# %%
# Evaluate DataFrame format for transposition; Review DataFrame format.
df_customers
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
# DataFrame format transposition is not necessary.

# %% [markdown]
# ### 04.02. Variable relevancy

# %%
# Evaluate variables for removal based on relevancy and data sufficiency; Review variables for relevancy.
df_customers
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
# Variables 'First Name' and 'Surnam' aren't relevant to this analysis and will be removed for efficiency.

# %%
# Review variables for data that is 90%+ null observations; Identify total record count.
df_customers.shape
# Out:
# (206209, 10)

# %%
# Identify null counts of all variables.
df_customers.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# Compare null counts to total record count; All variables have sufficient data.

# %%
# Remove irrelevant and insufficient variables; Preview the DataFrame without identified variables.
df_customers.drop(columns = ['First Name', 'Surnam'])
# Out:
#         user_id  Gender           STATE  Age date_joined  n_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017             3
# 1         33890  Female      New Mexico   36    1/1/2017             0
# 2         65803    Male           Idaho   35    1/1/2017             2
# 3        125935  Female            Iowa   40    1/1/2017             0
# 4        130797  Female        Maryland   26    1/1/2017             1
# ...         ...     ...             ...  ...         ...           ...
# 206204   168073  Female  North Carolina   44    4/1/2020             1
# 206205    49635    Male          Hawaii   62    4/1/2020             3
# 206206   135902  Female        Missouri   66    4/1/2020             2
# 206207    81095  Female      California   27    4/1/2020             1
# 206208    80148  Female        New York   55    4/1/2020             1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# ...

# %%
# Overwrite the DataFrame without identified variables.
df_customers = df_customers.drop(columns = ['First Name', 'Surnam'])

#Verify DataFrame
df_customers
# Out:
#         user_id  Gender           STATE  Age date_joined  n_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017             3
# 1         33890  Female      New Mexico   36    1/1/2017             0
# 2         65803    Male           Idaho   35    1/1/2017             2
# 3        125935  Female            Iowa   40    1/1/2017             0
# 4        130797  Female        Maryland   26    1/1/2017             1
# ...         ...     ...             ...  ...         ...           ...
# 206204   168073  Female  North Carolina   44    4/1/2020             1
# 206205    49635    Male          Hawaii   62    4/1/2020             3
# 206206   135902  Female        Missouri   66    4/1/2020             2
# 206207    81095  Female      California   27    4/1/2020             1
# 206208    80148  Female        New York   55    4/1/2020             1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# ...

# %% [markdown]
# ### 04.03. Variable name coherence

# %%
# Evaluate variable names for coherence; Review variable names.
df_customers
# Out:
#         user_id  Gender           STATE  Age date_joined  n_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017             3
# 1         33890  Female      New Mexico   36    1/1/2017             0
# 2         65803    Male           Idaho   35    1/1/2017             2
# 3        125935  Female            Iowa   40    1/1/2017             0
# 4        130797  Female        Maryland   26    1/1/2017             1
# ...         ...     ...             ...  ...         ...           ...
# 206204   168073  Female  North Carolina   44    4/1/2020             1
# 206205    49635    Male          Hawaii   62    4/1/2020             3
# 206206   135902  Female        Missouri   66    4/1/2020             2
# 206207    81095  Female      California   27    4/1/2020             1
# 206208    80148  Female        New York   55    4/1/2020             1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# ...

# %%
# Rename variables.
df_customers.rename(columns = {'Gender': 'gender', 'STATE': 'state', 'Age': 'age', 'n_dependants': 'dependents'}, inplace = True)

# Confirm variable names.
df_customers
# Out:
#         user_id  gender           state  age date_joined  dependents  \
# 0         26711  Female        Missouri   48    1/1/2017           3
# 1         33890  Female      New Mexico   36    1/1/2017           0
# 2         65803    Male           Idaho   35    1/1/2017           2
# 3        125935  Female            Iowa   40    1/1/2017           0
# 4        130797  Female        Maryland   26    1/1/2017           1
# ...         ...     ...             ...  ...         ...         ...
# 206204   168073  Female  North Carolina   44    4/1/2020           1
# 206205    49635    Male          Hawaii   62    4/1/2020           3
# 206206   135902  Female        Missouri   66    4/1/2020           2
# 206207    81095  Female      California   27    4/1/2020           1
# 206208    80148  Female        New York   55    4/1/2020           1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# 3          single   42049
# ...

# %% [markdown]
# ### 04.04. Variable data type accuracy

# %%
# Evaluate variable data types for accuracy; Review variable data types.
df_customers[['user_id', 'gender', 'state', 'age', 'date_joined', 'dependents', 'fam_status', 'income']].dtypes
# Out:
# user_id         int64
# gender         object
# state          object
# age             int64
# date_joined    object
# dependents      int64
# fam_status     object
# income          int64
# dtype: object

# %%
# Review variables for mixed data types.
for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].map(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)
  else:
  	print(f'No mixed data in column {col}.')
# Out:
# No mixed data in column user_id.
# No mixed data in column gender.
# No mixed data in column state.
# No mixed data in column age.
# No mixed data in column date_joined.
# No mixed data in column dependents.
# No mixed data in column fam_status.
# No mixed data in column income.

# %%
# All variable data types are accurate and consistent.

# %% [markdown]
# ### 04.05. Missing Values

# %%
# Identify null counts of all variables.
df_customers.isnull().sum()
# Out:
# user_id        0
# gender         0
# state          0
# age            0
# date_joined    0
# dependents     0
# fam_status     0
# income         0
# dtype: int64

# %%
# No null values are present.

# %% [markdown]
# ### 04.06. Duplicate Records

# %%
# Preview a subset DataFrame of duplicate records.
df_customers[df_customers.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, date_joined, dependents, fam_status, income]
# Index: []

# %%
# No duplicate records are present.

# %% [markdown]
# ### 04.07. Outlier Observations

# %%
# Review variable statistics for outliers.
df_customers.describe()
# Out:
#              user_id            age     dependents         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
# No outlier values identified.

# %%
# Review variable statistics for outliers.
df_ords_prods.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.243506e+07  3.243506e+07  3.243506e+07  3.243506e+07
# mean   1.709857e+06  1.710748e+06  1.029372e+05  1.714195e+01
# std    9.864641e+05  9.873006e+05  5.946651e+04  1.753496e+01
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556120e+05  8.559430e+05  5.142000e+04  5.000000e+00
# 50%    1.709136e+06  1.711047e+06  1.026110e+05  1.100000e+01
# 75%    2.565949e+06  2.565514e+06  1.543910e+05  2.400000e+01
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count        3.243506e+07       3.243506e+07            3.035696e+07
# mean         2.738815e+00       1.342498e+01            1.110414e+01
# std          2.090051e+00       4.246357e+00            8.778941e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
# Outliers identified: prices max is 99999

# Review scatterplot of variable with suspected outliers.
sns.scatterplot(x = 'prices', y = 'prices',data = df_ords_prods)
# Out:
# <Axes: xlabel='prices', ylabel='prices'>

# %%
# Remove outliers by converting them to NaN; Preview set of outliers.
df_ords_prods.loc[df_ords_prods['prices'] > 100]
# Out:
#           Unnamed: 0   order_id   user_id  order_number  orders_day_of_week  \
# 10030345       171.0   912404.0      17.0          12.0                 2.0
# 10030346       181.0   603376.0      17.0          22.0                 6.0
# 10030347      1944.0  3264360.0     135.0           2.0                 2.0
# 10030348      1945.0   892534.0     135.0           3.0                 0.0
# 10030349      5708.0   229704.0     342.0           8.0                 1.0
# ...              ...        ...       ...           ...                 ...
# 29194168   3386542.0  2249946.0  204099.0          29.0                 0.0
# 29194169   3386544.0  2363282.0  204099.0          31.0                 0.0
# 29194170   3391313.0  3181945.0  204395.0          13.0                 3.0
# 29194171   3405096.0  2486215.0  205227.0           7.0                 3.0
# 29194172   3405099.0  2232716.0  205227.0          10.0                 0.0
#
# ...

# %%
# Convert outliers to NaN.
df_ords_prods.loc[df_ords_prods['prices'] > 100, 'prices'] = np.nan
print(f'Conversion complete.')
# Out:
# Conversion complete.

# %%
# Verify with scatterplot.
sns.scatterplot(x = 'prices', y = 'prices',data = df_ords_prods)
# Out:
# <Axes: xlabel='prices', ylabel='prices'>

# %%
# Verify with statistics for outliers.
df_ords_prods.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number  \
# count  3.243506e+07  3.243506e+07  3.243506e+07  3.243506e+07
# mean   1.709857e+06  1.710748e+06  1.029372e+05  1.714195e+01
# std    9.864641e+05  9.873006e+05  5.946651e+04  1.753496e+01
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556120e+05  8.559430e+05  5.142000e+04  5.000000e+00
# 50%    1.709136e+06  1.711047e+06  1.026110e+05  1.100000e+01
# 75%    2.565949e+06  2.565514e+06  1.543910e+05  2.400000e+01
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count        3.243506e+07       3.243506e+07            3.035696e+07
# mean         2.738815e+00       1.342498e+01            1.110414e+01
# std          2.090051e+00       4.246357e+00            8.778941e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %% [markdown]
# ## 05. Combine DataFrames

# %%
# Identify matching key variables.
verify_df(df_customers)
# Out:
# Shape of the DataFrame: (206209, 8)
#
# DataFrame Preview:
#          user_id  gender           state  age date_joined  dependents  \
# 0         26711  Female        Missouri   48    1/1/2017           3
# 1         33890  Female      New Mexico   36    1/1/2017           0
# 2         65803    Male           Idaho   35    1/1/2017           2
# 3        125935  Female            Iowa   40    1/1/2017           0
# 4        130797  Female        Maryland   26    1/1/2017           1
# ...         ...     ...             ...  ...         ...         ...
# 206204   168073  Female  North Carolina   44    4/1/2020           1
# 206205    49635    Male          Hawaii   62    4/1/2020           3
# 206206   135902  Female        Missouri   66    4/1/2020           2
# 206207    81095  Female      California   27    4/1/2020           1
# 206208    80148  Female        New York   55    4/1/2020           1
#
#        fam_status  income
# 0         married  165665
# ...

# %%
verify_df(df_ords_prods)
# Out:
# Shape of the DataFrame: (32435070, 26)
#
# DataFrame Preview:
#            Unnamed: 0   order_id  user_id  order_number  orders_day_of_week  \
# 0                0.0  2539329.0      1.0           1.0                 2.0
# 1                1.0  2398795.0      1.0           2.0                 3.0
# 2                2.0   473747.0      1.0           3.0                 3.0
# 3                3.0  2254736.0      1.0           4.0                 4.0
# 4                4.0   431534.0      1.0           5.0                 4.0
# ...              ...        ...      ...           ...                 ...
# 32435065         NaN        NaN      NaN           NaN                 NaN
# 32435066         NaN        NaN      NaN           NaN                 NaN
# 32435067         NaN        NaN      NaN           NaN                 NaN
# 32435068         NaN        NaN      NaN           NaN                 NaN
# 32435069         NaN        NaN      NaN           NaN                 NaN
#
# ...

# %%
# Preview the merger of DataFrames df_ords_prods and df_customers using key variable user_id.
df_ords_prods.merge(df_customers, on = ['user_id'])
# Out:
#           Unnamed: 0   order_id   user_id  order_number  orders_day_of_week  \
# 0                0.0  2539329.0       1.0           1.0                 2.0
# 1                1.0  2398795.0       1.0           2.0                 3.0
# 2                2.0   473747.0       1.0           3.0                 3.0
# 3                3.0  2254736.0       1.0           4.0                 4.0
# 4                4.0   431534.0       1.0           5.0                 4.0
# ...              ...        ...       ...           ...                 ...
# 32435054   1768145.0   156685.0  106143.0          26.0                 4.0
# 32435055   1101646.0   484769.0   66343.0           1.0                 6.0
# 32435056   1101647.0  1561557.0   66343.0           2.0                 1.0
# 32435057   1101648.0   276317.0   66343.0           3.0                 6.0
# 32435058   1101649.0  2922475.0   66343.0           4.0                 1.0
#
# ...

# %%
# Merge DataFrames df_ords_prods and df_customers using key variable user_id.
df_merged = df_ords_prods.merge(df_customers, on = ['user_id'])
df_merged
# Out:
#           Unnamed: 0   order_id   user_id  order_number  orders_day_of_week  \
# 0                0.0  2539329.0       1.0           1.0                 2.0
# 1                1.0  2398795.0       1.0           2.0                 3.0
# 2                2.0   473747.0       1.0           3.0                 3.0
# 3                3.0  2254736.0       1.0           4.0                 4.0
# 4                4.0   431534.0       1.0           5.0                 4.0
# ...              ...        ...       ...           ...                 ...
# 32435054   1768145.0   156685.0  106143.0          26.0                 4.0
# 32435055   1101646.0   484769.0   66343.0           1.0                 6.0
# 32435056   1101647.0  1561557.0   66343.0           2.0                 1.0
# 32435057   1101648.0   276317.0   66343.0           3.0                 6.0
# 32435058   1101649.0  2922475.0   66343.0           4.0                 1.0
#
# ...

# %% [markdown]
# ## 06. Export Data

# %%
# Define the folder path and file name.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged.pkl'

# Create the full file path.
file_path = os.path.join(folder_path, '02 Data', 'Prepared Data', file_name)

# Export the DataFrame to a PKL file.
df_merged.to_pickle(file_path)

print(f'DataFrame exported to {file_path}.')
# Out:
# DataFrame exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/02 Data/Prepared Data/merged.pkl.

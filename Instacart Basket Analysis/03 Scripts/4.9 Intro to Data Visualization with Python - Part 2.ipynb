# %% [markdown]
# ## 00. Table of Contents

# %% [markdown]
# 01. Import Libraries
# 02. Import Data
# 03. Verify DataFrame
# 04. Create Visualizations

# %% [markdown]
# ## 01. Import Libraries

# %%
# Import coding libraries.
import pandas as pd
import numpy as np
import os

# Import visualization libraries.
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# Confirm execution.
print(f'Import libraries completed')
# Out:
# Import libraries completed

# %% [markdown]
# ## 02. Import Data

# %%
# Import file as a DataFrame.
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged.pkl'
df_merged = pd.read_pickle(os.path.join(folder_path, '02 Data', 'Prepared Data', file_name))
df_merged
# Out:
#           Unnamed: 0   order_id   user_id  order_number  orders_day_of_week  \
# 0                0.0  2539329.0       1.0           1.0                 2.0
# 1                1.0  2398795.0       1.0           2.0                 3.0
# 2                2.0   473747.0       1.0           3.0                 3.0
# 3                3.0  2254736.0       1.0           4.0                 4.0
# 4                4.0   431534.0       1.0           5.0                 4.0
# ...              ...        ...       ...           ...                 ...
# 32435054   1768145.0   156685.0  106143.0          26.0                 4.0
# 32435055   1101646.0   484769.0   66343.0           1.0                 6.0
# 32435056   1101647.0  1561557.0   66343.0           2.0                 1.0
# 32435057   1101648.0   276317.0   66343.0           3.0                 6.0
# 32435058   1101649.0  2922475.0   66343.0           4.0                 1.0
#
# ...

# %% [markdown]
# ## 03. Verify DataFrame

# %%
# Set display option to show all columns
pd.set_option('display.max_columns', None)

# Define and execute DataFrame verification function.
def verify_df(df):
    """
    Prints the shape and the first n rows of a DataFrame.
    
    Parameters:
    DF : The DataFrame to display.
    n (int) : The number of rows to display from the top of the DataFrame. Default is 5.
    """
    print(f"Shape of the DataFrame: {df.shape}")
    print(f"\nDataFrame Preview:\n", df)

# Verify DataFrame
verify_df(df_merged)
# Out:
# Shape of the DataFrame: (32435059, 33)
#
# DataFrame Preview:
#            Unnamed: 0   order_id   user_id  order_number  orders_day_of_week  \
# 0                0.0  2539329.0       1.0           1.0                 2.0
# 1                1.0  2398795.0       1.0           2.0                 3.0
# 2                2.0   473747.0       1.0           3.0                 3.0
# 3                3.0  2254736.0       1.0           4.0                 4.0
# 4                4.0   431534.0       1.0           5.0                 4.0
# ...              ...        ...       ...           ...                 ...
# 32435054   1768145.0   156685.0  106143.0          26.0                 4.0
# 32435055   1101646.0   484769.0   66343.0           1.0                 6.0
# 32435056   1101647.0  1561557.0   66343.0           2.0                 1.0
# 32435057   1101648.0   276317.0   66343.0           3.0                 6.0
# ...

# %% [markdown]
# ## 04. Create Visualizations

# %% [markdown]
# ### 01. Bar Chart

# %%
# Preview the bar chart.
df_merged['orders_day_of_week'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='orders_day_of_week'>

# %%
# Create the bar chart.
merged_bar_chart = df_merged['orders_day_of_week'].value_counts().sort_index().plot.bar()

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_bar_chart.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_bar_chart.figure.savefig(file_path)

print(f"Plot exported to {file_path}")
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_bar_chart.png

# %% [markdown]
# ### 02. Histogram

# %%
# Preview the histogram.
df_merged['prices'].plot.hist(bins = 75)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Create the histogram.
merged_hist = df_merged['prices'].plot.hist(bins = 75)

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_hist.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_hist.figure.savefig(file_path)

print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_hist.png

# %% [markdown]
# ### 03. Scatterplot

# %%
# Preview the scatterplot.
sns.scatterplot(x = 'prices', y = 'prices',data = df_merged)
# Out:
# <Axes: xlabel='prices', ylabel='prices'>

# %%
# Create the scatterplot.
merged_scatter = sns.scatterplot(x = 'prices', y = 'prices',data = df_merged)

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_scatter.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_scatter.figure.savefig(file_path)

print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_scatter.png

# %% [markdown]
# ### 04. Line Chart

# %% [markdown]
# #### 01. Create Samples

# %%
# Create sample subsets.

# Set the seed.
np.random.seed(4)

# Create a list to store boolean values.
dev = np.random.rand(len(df_merged)) <= 0.7

# Create DataFrame from the big sample percentage.
df_big_sample = df_merged[dev]

# Create DataFrame from the small sample percentage.
df_small_sample = df_merged[~dev]

# Execution confirmation.
print(f"Sample subsets created.")
# Out:
# Sample subsets created.

# %%
# Verify the sample subset sizes.
len(df_merged) - (len(df_big_sample) + len(df_small_sample))
# Out:
# 0

# %% [markdown]
# #### 02. Sample modification

# %%
# Modify small sample DataFrame subset for efficiency; Create subset of small sample DataFrame from specified variables. 

# Preview small sample DataFrame subset.
df_small_sample[['orders_day_of_week','prices']]
# Out:
#           orders_day_of_week  prices
# 0                        2.0     9.0
# 2                        3.0     9.0
# 3                        4.0     9.0
# 6                        1.0     9.0
# 10                       2.0    12.5
# ...                      ...     ...
# 32435010                 1.0    12.0
# 32435017                 1.0     8.9
# 32435030                 3.0    10.7
# 32435043                 0.0    10.7
# 32435045                 0.0    10.7
#
# [9729960 rows x 2 columns]

# %%
# Create DataFrame subset from small sample DataFrame.
df_small_sample_mod = df_small_sample[['orders_day_of_week','prices']]
df_small_sample_mod
# Out:
#           orders_day_of_week  prices
# 0                        2.0     9.0
# 2                        3.0     9.0
# 3                        4.0     9.0
# 6                        1.0     9.0
# 10                       2.0    12.5
# ...                      ...     ...
# 32435010                 1.0    12.0
# 32435017                 1.0     8.9
# 32435030                 3.0    10.7
# 32435043                 0.0    10.7
# 32435045                 0.0    10.7
#
# [9729960 rows x 2 columns]

# %% [markdown]
# #### 03. Create line graph

# %%
# Preview the line graph.
sns.lineplot(data = df_small_sample_mod, x = 'orders_day_of_week',y = 'prices')
# Out:
# <Axes: xlabel='orders_day_of_week', ylabel='prices'>

# %%
# Create the line graph.
merged_line_chart = sns.lineplot(data = df_small_sample_mod, x = 'orders_day_of_week',y = 'prices')

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_line_chart.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_line_chart.figure.savefig(file_path)

print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_line_chart.png

# %% [markdown]
# ### 05. Histogram - order_hour_of_day

# %%
# Preview the histogram.
df_merged['order_hour_of_day'].plot.hist(bins = 75)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# This chart shows the frequency of when purchases are made broken down by hour. The bell curve indicates that purchasing frequency is at its lowest at 3AM, increases dramatically between 5AM and 10AM, peaks at 10AM, fluctuates until 3PM, then decreases until 3AM.

# %%
# Create the histogram.
merged_hist_order_hour = df_merged['order_hour_of_day'].plot.hist(bins = 75)

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_hist_order_hour.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_hist_order_hour.figure.savefig(file_path)

print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_hist_order_hour.png

# %% [markdown]
# ### 06. Bar Chart - loyalty_flag

# %%
# Preview the bar chart.
df_merged['loyalty_flag'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='loyalty_flag'>

# %%
# Create the bar chart.
merged_bar_chart_loyalty = df_merged['loyalty_flag'].value_counts().plot.bar()

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_bar_chart_loyalty.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_bar_chart_loyalty.figure.savefig(file_path)

print(f"Plot exported to {file_path}")
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_bar_chart_loyalty.png

# %% [markdown]
# ### 07. Line Chart - prices vs order_hour_of_day

# %% [markdown]
# #### 01. Sample modification

# %%
# Modify small sample DataFrame subset for efficiency; Create subset of small sample DataFrame from specified variables. 

# Preview small sample DataFrame subset.
df_small_sample[['order_hour_of_day','prices']]
# Out:
#           order_hour_of_day  prices
# 0                       8.0     9.0
# 2                      12.0     9.0
# 3                       7.0     9.0
# 6                       9.0     9.0
# 10                      8.0    12.5
# ...                     ...     ...
# 32435010               22.0    12.0
# 32435017               10.0     8.9
# 32435030               17.0    10.7
# 32435043                1.0    10.7
# 32435045                8.0    10.7
#
# [9729960 rows x 2 columns]

# %%
# Create DataFrame subset from small sample DataFrame.
df_small_sample_mod_hour = df_small_sample[['order_hour_of_day','prices']]
df_small_sample_mod_hour
# Out:
#           order_hour_of_day  prices
# 0                       8.0     9.0
# 2                      12.0     9.0
# 3                       7.0     9.0
# 6                       9.0     9.0
# 10                      8.0    12.5
# ...                     ...     ...
# 32435010               22.0    12.0
# 32435017               10.0     8.9
# 32435030               17.0    10.7
# 32435043                1.0    10.7
# 32435045                8.0    10.7
#
# [9729960 rows x 2 columns]

# %% [markdown]
# #### 02. Create line graph

# %%
# Preview the line graph.
sns.lineplot(data = df_small_sample_mod_hour, x = 'order_hour_of_day',y = 'prices')
# Out:
# <Axes: xlabel='order_hour_of_day', ylabel='prices'>

# %%
# Create the line graph.
merged_line_chart_hour = sns.lineplot(data = df_small_sample_mod_hour, x = 'order_hour_of_day',y = 'prices')

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_line_chart_hour.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_line_chart_hour.figure.savefig(file_path)

print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_line_chart_hour.png

# %% [markdown]
# ### 08. Line Chart - age vs. dependents

# %% [markdown]
# #### 01. Sample modification

# %%
# Modify small sample DataFrame subset for efficiency; Create subset of small sample DataFrame from specified variables. 

# Preview small sample DataFrame subset.
df_small_sample[['age','dependents']]
# Out:
#           age  dependents
# 0          31           3
# 2          31           3
# 3          31           3
# 6          31           3
# 10         31           3
# ...       ...         ...
# 32435010   28           2
# 32435017   57           1
# 32435030   25           0
# 32435043   25           0
# 32435045   25           0
#
# [9729960 rows x 2 columns]

# %%
# Create DataFrame subset from small sample DataFrame.
df_small_sample_mod_age = df_small_sample[['age','dependents']]
df_small_sample_mod_age
# Out:
#           age  dependents
# 0          31           3
# 2          31           3
# 3          31           3
# 6          31           3
# 10         31           3
# ...       ...         ...
# 32435010   28           2
# 32435017   57           1
# 32435030   25           0
# 32435043   25           0
# 32435045   25           0
#
# [9729960 rows x 2 columns]

# %%
# Preview the line graph.
sns.lineplot(data = df_small_sample_mod_age, x = 'age',y = 'dependents')
# Out:
# <Axes: xlabel='age', ylabel='dependents'>

# %% [markdown]
# There don't appear to be any consistent trends for the number of dependents based on age or age range. One trend to note is that the average number of dependents for everyone falls around 1.5 dependents. No single age group falls below an average of 1 dependent.

# %%
# Create the line graph.
merged_line_chart_age_dependents = sns.lineplot(data = df_small_sample_mod_age, x = 'age',y = 'dependents')

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_line_chart_age_dependents.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_line_chart_age_dependents.figure.savefig(file_path)

print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_line_chart_age_dependents.png

# %% [markdown]
# ### 09. Scatterplot - age vs income

# %%
# Preview the scatterplot.
sns.scatterplot(x = 'age', y = 'income',data = df_merged)
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %% [markdown]
# There is a significant income hike for a portion of customers beginning at the age of 41.

# %%
# Create the scatterplot.
merged_scatter_age_income = sns.scatterplot(x = 'age', y = 'income',data = df_merged)

# %%
# Export plot as an image
# Define the folder path and file name
folder_path = r'/Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/'
file_name = 'merged_scatter_age_income.png'

# Validate folder
os.makedirs(folder_path, exist_ok=True)

# Create the full file path
file_path = os.path.join(folder_path, '04 Analysis', 'Visualizations', file_name)

# Export the plot to an image file
merged_scatter_age_income.figure.savefig(file_path)

print(f'Plot exported to {file_path}')
# Out:
# Plot exported to /Users/bertpearce/Documents/Python Projects/2024.05.22 Instacard Basket Analysis/04 Analysis/Visualizations/merged_scatter_age_income.png
